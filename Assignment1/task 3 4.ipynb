# %%
from IPython.display import Image, display

# Replace 'figure1.jpg' with the path to your actual image
image_path = 'figure1.jpg'

# display
display(Image(filename=image_path, width=220))

# %% [markdown]
# ## Statistical Decision Making
# ### Task 3
#
#
#
# Answer the following questions. All answers must be justified.
#
# #### *Part A*
# The numbers in Figure 1 show the probability of the respective event to happen
# (e.g., the probability for the event $X=1$ and $Y=1$ is $0.02$). Is this table a
# probability table? If so, why?
#
# Given that \$( \sum_Y \sum_X p_{X, Y}(x, y) = 0.4 + 0.14 + 0.05 + 0.02 + 0.26 + 0.13 = 1 \)$,
#
# thus,
#
#
# \begin{align*}
# &\text{Total Probability: } \\
# &\quad \text{for } p_{X, Y}(x, y) \geq 0 \quad \forall\; (x, y) \in \{\mathbf{X} \times \mathbf{Y}\} \\
# \end{align*}
#
#
# Figure 1 is a probability table.

# %% [markdown]
# #### *Part B*
# Based on Figure 1, give the conditional expectation $\mathbb{E}_{Y \mid X=2}[Y]$ and the probability of the event $X=1$ under the condition that $Y=3$.
#
# To determine \(Pr(X=1 \mid Y=3)\), we employ the conditional probability formula:
#
#
# \begin{align*}
# & \text{Given } Pr(X=1 \mid Y=3) = \frac{Pr(X=1 \cap Y=3)}{Pr(Y=3)} \\
# & \text{Which simplifies to } Pr(X=1 \mid Y=3) = \frac{Pr(X=1 \cap Y=3)}{\sum_X Pr(X, Y=3)} \\
# & \text{Substituting in the provided values, we get } Pr(X=1 \mid Y=3) = \frac{0.13}{0.13 + 0.05} \\
# & \text{Therefore, } Pr(X=1 \mid Y=3) = \frac{13}{18} \approx 0.722
# \end{align*}
#
#
# Next, let's compute the conditional expectation \(\mathbb{E}_{Y \mid X=2}[Y]\):
#
#
# \begin{align*}
# & \text{Given } \mathbb{E}_{Y \mid X=2}[Y] = \sum_Y Y\;Pr(Y \mid X=2) \\
# & \text{Which further simplifies to } \mathbb{E}_{Y \mid X=2}[Y] = \frac{1}{Pr(X=2)}\; \sum_Y Y\; Pr(Y \cap X=2) \\
# & \text{Substituting values, we get } \mathbb{E}_{Y \mid X=2}[Y] = \frac{1}{\sum_Y Pr(X=2, Y)}\sum_Y Y\;Pr(Y \cap X=2) \\
# & \text{Therefore, } \mathbb{E}_{Y \mid X=2}[Y] = \frac{1}{0.4+0.14+0.05}(1\times 0.4 + 2\times 0.14 + 3\times 0.05) \\
# & \text{Hence, } \mathbb{E}_{Y \mid X=2}[Y] = \frac{83}{59} \approx 1.4068
# \end{align*}

# %% [markdown]
# #### *Part C*
# Is the function $p(x, y)$ given by
# $$
# p(x, y) = \begin{cases}
# 1 & \quad \text{for } 0\leq x\leq 1\text{, } 0\leq y\leq \frac{1}{2} \\
# 0 & \quad \text{otherwise} \end{cases}
# $$
# a joint density function for two random variables?
#
# Given that
#
#
# \begin{align*}
# p(x,y)&=\int_y \int_x p(x, y)\; \mathrm{d}x \mathrm{d}y \\
# & = \int_0^{1/2} \int_0^1 1\; \mathrm{d}x \mathrm{d}y \\
# & = \int_0^{1/2} x\mid_0^1\; \mathrm{d}y \\
# & = \int_0^{1/2} 1\; \mathrm{d}y \\
# & = y\mid_0^{1/2} \\
# & = \frac{1}{2}\\
# p(x,y) \;&\neq 1
# \end{align*}
#
#
# So, the function \(p(x, y)\) is not a density function.

# %% [markdown]
# #### *Part D*
# For two random variables $X$ and $Y$, the joint density function is given by
# $$
# p(x, y) = \begin{cases}
# 2\mathit{e}^{-(x+y)} & \quad \text{for } 0\leq x\leq y\text{, } 0\leq y \\
# 0 & \quad \text{otherwise.} \end{cases}
# $$
# What are the marginal density functions for $X$ and $Y$ respectively?
#
# For the marginal density function of \( X \):
#
#
# \begin{align*}
# \text{Given } p(x)& = \int_x^\infty p(x, y)\; \mathrm{d}y\\
# & = \int_x^\infty 2e^{-(x+y)}\; \mathrm{d}y\\
# & = 2e^{-x} \int_x^∞ e^{-y}\; \mathrm{d}y\\
# & = 2e^{-x} \big[-e^\infty+e^{-x} \big]\\
# & = 2e^{-x} \big[0+e^{-x} \ big]\\
# p(x) &= 2e^{-2x}\\
# \end{align*}
#
# For the marginal density function of \( Y \):
#
#
# \begin{align*}
#  \text{Given } p(y) &= \int_0^y 2e^{-(x+y)}\; \mathrm{d}x\\
# & = 2e^{-y} \int_0^y e^{-x}\; \mathrm{d}x\\
# & = 2e^{-y} \big[ -e^{-y} + 1 \big]\\
# p(y) &= 2e^{-y} \big( -e^{-y} + 1 \big)\\
# \end{align*}

# %% [markdown]
# #### *Part E*
# Let the joint density function of two random variables $X$ and $Y$ be given by
# $$
# p(x, y) = \begin{cases}
# \frac{1}{15}(2x+4y) & \quad \text{for } 0\leq x\leq 3\text{, } 0\leq y\leq 1 \\
# 0 & \quad \text{otherwise.} \end{cases}
# $$
# Determine the probability for $X\leq 2$ under the condition that $Y = \frac{1}{2}$
#
# To derive the marginal density function for \( Y \), we integrate the joint density function over the range of \( x \):
#
#
#
# # Calculating Conditional Probability
#
# Given the joint density function
#  p(x, y) =
# \begin{cases}
# \frac{1}{15}(2x+4y) & \text{for } 0 \leq x \leq 3, \, 0 \leq y \leq 1 \\
# 0 & \text{otherwise}
# \end{cases}
#
#
#
# ### step 1: Calculate p(y)
#
#
# \begin{aligned}
# p(y)& = \int_0^3 \frac{1}{15}(2x+4y)\; \mathrm{d}x\\
# & = \frac{1}{15} \left(\frac{1}{5}(4y+3)x^2\right)\Big|_{x=0}^3 \\
# p(y) &= \frac{1}{5} (4y+3) \\
# \end{aligned}
#
#
#
# ### Step 2: Calculate $ Pr(X\leq 2 \mid Y=\frac{1}{2}) $
#
#
# \begin{align*}
#  Pr(X\leq 2 \mid Y=\frac{1}{2})& = \int_0^2 \frac{p(x, y)}{p(y)}\ \mathrm{d}x\\
#  &= \int_0^2 \frac{\frac{1}{15}(2x+4y)}{\frac{1}{5}(4y+3)}\mathrm{d}x\\
#  &= \int_0^2 \frac{\frac{1}{15}(2x+4*\frac{1}{2})}{\frac{1}{5}(4*\frac{1}{2}+3)}\mathrm{d}x\\
# &= \int_0^2 \frac{2x+2}{15}\; \mathrm{d}x\\
# &= \frac{1}{15} (x^2+2x)\Big|_0^2\\
# Pr(X\leq 2\mid Y=\frac{1}{2}) &= \frac{8}{15}
# \end{align*}
#
# These steps outline the calculations for p(y) and $ Pr(X\leq 2 \mid Y=\frac{1}{2})$.

# %% [markdown]
# **Task 4: Proving Symmetry and Positive Semidefiniteness of Covariance Matrix**
#
# To demonstrate that the covariance matrix (C) for any random variable (X in R^p) possesses the properties of symmetry and positive semidefiniteness, i.e., (C = C^T) and (x^T Cx >= 0) for any covariance matrix (C in R^{p x p}) and any vector (x in R^p), we can express this mathematically:
#
# 1. **Symmetry (C = C^T):**
#
#    Because for any covariance matrix C, it holds that C = C^T.
#
# 2. **Positive Semidefiniteness (x^T Cx >= 0):**
#
#    Because for any covariance matrix C and any vector x, it is true that x^T Cx >= 0.
#
# **Symmetry Proof:**
#
#
# # Proving $C^T = C$:
#
# Given the covariance matrix $C = E((X-μ)(X-μ)^T)$, we want to show that $C^T = C$.
#
# \begin{align*}
# 1. \quad &\text{Expand the covariance matrix:} \\
# & C = E((X-μ)(X-μ)^T) \\
# &= E((X-μ)(X^T-μ^T)) \\
# &= E(XX^T-Xμ^T-μX^T+μμ^T) \\
# &= E(XX^T)-E(Xμ^T)-E(μX^T)+E(μμ^T) \\
# &= E(XX^T)-μμ^T \\[10pt]
# 2. \quad &\text{Transpose the covariance matrix:} \\
# & C^T = E(XX^T)^T-μμ^T \\
# &= E((X^T)^T(X)^T)-μ^Tμ^T \\
# &= E(XX^T)-μμ^T
# \end{align*}
#
#
# Therefore $ C^T = C $
#
#
# # Proving $x^T C x >= 0$:
#
# Now, let's prove that $x^T C x >= 0$ for any vector x.
#
# 1. Start with the definition of C:
#    $ C = E((X-μ)(X-μ)^T)$
#
# 2. Consider x^T C x:
# \begin{align*}
# x^T C x &= x^T E((X-\mu)(X-\mu)^T) x \\
# &= E(x^T(X-\mu)(X-\mu)^T x) \\
# &= E((x^T(X-\mu))(x^T(X-\mu))^T) \\
# &= E(Y Y^T) \quad \text{where } Y = x^T(X-\mu)
# \end{align*}
#
#
#
# 3. Since Y is a vector, $Y^T Y$ is the squared magnitude of Y, which is non-negative:
#   $x^T C x = E(Y^2) \geq 0$ where $Y = x^T C x$
#
#
#
# Therefore, $x^T C x >= 0$.
